# %% [markdown]
# At first, we are importing necessary libraries.

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# We are loading the dataset using “Keras” from the imported version of tensor flow.

# %%
(x_train, y_train),\
	(x_test, y_test) = keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# Now we are displaying the shape and image of the single image in the dataset. The image size contains a 28*28 matrix and length of the training set is 60,000 and the testing set is 10,000.

# %%
len(x_train)
len(x_test)
x_train[0].shape
plt.matshow(x_train[0])

# %% [markdown]
# In the next step, we shall normalize the dataset.

# %%
# Normalizing the dataset
x_train = x_train/255
x_test = x_test/255

# Flatting the dataset in order
# to compute for model building
x_train_flatten = x_train.reshape(len(x_train), 28*28)
x_test_flatten = x_test.reshape(len(x_test), 28*28)

# %% [markdown]
# We are now building a neural network with single-layer perception. Here we can observe as the model is a single-layer perceptron that only contains one input layer and one output layer. There is no presence of the hidden layer.

# %%
model = keras.Sequential([
	keras.layers.Dense(10, input_shape=(784,),
					activation='sigmoid')
])
model.compile(
	optimizer='adam',
	loss='sparse_categorical_crossentropy',
	metrics=['accuracy'])

model.fit(x_train_flatten, y_train, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4709 - accuracy: 0.8773
# Epoch 2/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3039 - accuracy: 0.9157
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2836 - accuracy: 0.9203
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2732 - accuracy: 0.9237
# Epoch 5/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2664 - accuracy: 0.9258
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2618 - accuracy: 0.9273
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2586 - accuracy: 0.9285
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 0.2556 - accuracy: 0.9290
# Epoch 9/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2533 - accuracy: 0.9301
# Epoch 10/10
# ...

# %% [markdown]
# We shall now compute the output accuracy of the model on the testing data.

# %%
model.evaluate(x_test_flatten, y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.2653 - accuracy: 0.9256
# [0.26532381772994995, 0.925599992275238]
